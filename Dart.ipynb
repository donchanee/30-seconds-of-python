# %% [markdown]
# <a href="https://colab.research.google.com/github/donchanee/30-seconds-of-python/blob/master/Dart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from io import BytesIO
import pandas as pd

# %%
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36"
user_agent
# Out:
# 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36'

# %%
url = "http://dart.fss.or.kr/pdf/download/excel.do?rcp_no=20201116001248&dcm_no=7549051&lang=ko"

# %%
import requests

resp = requests.get(url, headers={"user-agent": user_agent})

# %%
resp.content
# Out:
# b'\xd0\xcf\x11\xe0\xa1\xb1\x1a\xe1\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00>\x00\x03\x00\xfe\xff\t\x00\x06\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00d\x00\x00\x00\x00\x00\x00\x00\x00\x10\x00\x00\xfe\xff\xff\xff\x00\x00\x00\x00\xfe\xff\xff\xff\x00\x00\x00\x00c\t\x08\x10\x00\x00\x06\x05\x00\xf2\x15\xcc\x07\x00\x00\x00\x00\x06\x00\x00\x00\xe1\x00\x02\x00\xb0\x04\xc1\x00\x02\x00\x00\x00\xe2\x00\x00\x00\\\x00p\x00Java Excel API v2.6.12                                                                                          B\x00\x02\x00\xe4\x04a\x01\x02\x00\x00\x00=\x01\x16\x00\x01\x00\x02\x00\x03\x00\x04\x00\x05\x00\x06\x00\x07\x00\x08\x00\t\x00\n\x00\x0b\x00\x9c\x00\x02\x00\x0e\x00\x19\x00\x02\x00\x00\x00\x12\x00\x02\x00\x00\x00\x13\x00\x02\x00\x00\x00\xaf\x01\x02\x00\x00\x00\xbc\x01\x02\x00\x00\x00=\x00\x12\x00h\x01\x0e\x01\\:\xbe#8\x00\x00\x00\x00\x00\x01\x00X\x02@\x00\x02\x00\x00\x00\x8d\x00\x02\x00\x00\x00"\x00\x02\x00\x00\x00\x0e\x00\x02\x00\x01\x00\xb7\x01\x02\x00\x00\x00\xda\x00\x02\x00\x00\x001\x00\x1a\x00\xc8\x00\x00\x00\xff\x7f\x90\x01\x00\x00\x00\x00\x00\x00\x05\x01A\x00r\x00i\x00a\x00l\x001\x00\x1a\x00\xc8\x00\x00\x00\xff\x7f\x90\x01\x00\x00\x00\x00\x00\x00\x05\x01A\x00r\x00i\x00a\x00l\x001\x00\x1a\x00\xc8\x00\x00\x00\xff\x7f\x90\x01\x00\x00\x00\x00\x00\x00\x05\x01A\x00r\x00i\x00a\x00l\x001\x00\x1a\x00\xc8\x00\x00\x00\xff\x7f\x90\x01\x00\x00\x00\x00\x00\x00\x05\x01A\x00r\x00i\x00a\x00l\x001\x00\x14\x00@\x01\x00\x00\xff\x7f\xbc\x02\x00\x00\x00\x00\x00\x00\x02\x01t\xad\xbc\xb91\x00\x14\x00\xc8\x00\x00\x00\xff\x7f\xbc\x02\x00\x00\x00\x00\x00\x00\x02\x01t\xad\xbc\xb91\x00\x14\x00\xc8\x00\x00\x00\xff\x7f\x90\x01\x00\x00\x00\x00\x00\x00\x02\x01t\xad\xbc\xb91\x00\x14\x00\xf0\x00\x00\x00\xff\x7f\xbc\x02\x00\x00\x00\x00\x00\x00\x02\x01t\xad\xbc\xb91\x00\x14\x00\xdc\x00\x00\x00\xff\x7f\x90\x01\x00\x00\x00\x00\x00\x00\x02\x01t\xad\xbc\xb9\x1e\x04\x1f\x00\xa4\x00\r\x00\x01#\x00,\x00#\x00#\x000\x00;\x00(\x00#\x00,\x00#\x00#\x000\x00)\x00\xe0\x00\x14\x00\x00\x00\x00\x00\xf5\xff \x00\x00\xfc\x00\x00\x00\x00\x00\x00\x00\x00\xc0 \xe0\x00\x14\x00\x01\x00\x00\x00\xf5\xff \x00\x00\xfc\x00\x00\x00\x00\x00\x00\x00\x00\xc0 \xe0\x00\x14\x00\x01\x00\x00\x00\xf5\xff \x00\x00\xfc\x00\x00\x00\x00\x00 ...

# %%
B = BytesIO(resp.content)

pd.read_excel(B)
# Out:
#             Unnamed: 0          Unnamed: 1  ... Unnamed: 4 Unnamed: 5
# 0                 문서정보                 NaN  ...        NaN        NaN
# 1      보고서 유형 : 3분기보고서        정정공시여부 : 아니오  ...        NaN        NaN
# 2                  NaN                 NaN  ...        NaN        NaN
# 3                  NaN                 NaN  ...        NaN        NaN
# 4   문서작성일 : 2020-09-30  비교표시 재무제표 작성여부 : 예  ...        NaN        NaN
# ..                 ...                 ...  ...        ...        ...
# 62               재무상태표             유동/비유동법  ...        NaN        NaN
# 63             포괄손익계산서      손익/기타포괄손익 개별작성  ...        NaN        NaN
# 64                 NaN              비용의 기능  ...        NaN        NaN
# 65                 NaN            세후기타포괄손익  ...        NaN        NaN
# 66               현금흐름표                 간접법  ...        NaN        NaN
#
# [67 rows x 6 columns]

# %%
data = pd.read_excel(B, sheet_name="연결 재무상태표", skiprows=5)

data.to_csv("연결 재무상태표.csv")

# %%
sheets = ["연결 재무상태표", "연결 손익계산서", "연결 포괄손익계산서"]

for sheet in sheets:
  data = pd.read_excel(B, sheet_name=sheet, skiprows=5)
  data.to_csv(sheet+'.csv')

# %%
url2 = "http://dart.fss.or.kr/pdf/download/excel.do?rcp_no=20200814001766&dcm_no=7446167&lang=ko"

resp = requests.get(url2, headers={"user-agent": user_agent})

# %%
for period, urls in zip(["20.11_", "20.08_"], [url, url2]):
  resp = requests.get(urls, headers={"user-agent": user_agent})
  B = BytesIO(resp.content)
  for sheet in sheets:
    data = pd.read_excel(B, sheet_name=sheet, skiprows=5)
    data.to_csv(period + sheet + '.csv')

# %%
def download_excel(url, period, company):
  resp = requests.get(urls, headers={"user-agent": user_agent})
  B = BytesIO(resp.content)
  for sheet in sheets:
    data = pd.read_excel(B, sheet_name=sheet, skiprows=5)
    data.to_csv(period + '_' + company + '_' + sheet + '.csv')

# %%
rcp_no = "20200814001766"
dcm_no = "7446167"

url_type = "http://dart.fss.or.kr/pdf/download/excel.do?rcp_no=" + rcp_no + "&dcm_no=" + dcm_no + "&lang=ko"
